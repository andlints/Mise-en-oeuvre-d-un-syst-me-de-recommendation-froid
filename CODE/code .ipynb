# %%
import ot
import numpy as np
import pandas as pd
import csv
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
import random
from sklearn.metrics.pairwise import cosine_similarity
from scipy.spatial.distance import cosine
from numpy.linalg import norm

# %% [markdown]
# ### DATASETS

# %%
movies = pd.read_csv("../DATASETS/ml-20m/movies.csv")

# %%
genome_scores = pd.read_csv("../DATASETS/ml-20m/genome-scores.csv")

# %%
genome_tags = pd.read_csv("../DATASETS/ml-20m/genome-tags.csv")

# %%
ratings = pd.read_csv("../DATASETS/ml-20m/ratings.csv")

# %%
tags = pd.read_csv("../DATASETS/ml-20m/tags.csv")

# %%
links = pd.read_csv("../DATASETS/ml-20m/links.csv")

# %%
movies_ratings_data = movies.merge(ratings, on = 'movieId', how='inner')

# %% [markdown]
# ### Binarisation des données

# %%
# supprimer films sans tag

# %%
tags.isnull().any()
# Out:
# userId       False
# movieId      False
# tag           True
# timestamp    False
# dtype: bool

# %%
tags = tags.dropna()

# %%
# supprimer utilisateurs sans interaction, ie sans note
# Tout est déjà supprimé

# %% [markdown]
# ### I - Matrice de coût

# %%
(movies_ratings_data[movies_ratings_data.userId == 1]).head(5)
# Out:
#         movieId                                              title  \
# 49695         2                                     Jumanji (1995)
# 346885       29  City of Lost Children, The (Cité des enfants p...
# 366121       32          Twelve Monkeys (a.k.a. 12 Monkeys) (1995)
# 526043       47                        Seven (a.k.a. Se7en) (1995)
# 582574       50                         Usual Suspects, The (1995)
#
#                                         genres  userId  rating   timestamp
# 49695               Adventure|Children|Fantasy       1     3.5  1112486027
# 346885  Adventure|Drama|Fantasy|Mystery|Sci-Fi       1     3.5  1112484676
# 366121                 Mystery|Sci-Fi|Thriller       1     3.5  1112484819
# 526043                        Mystery|Thriller       1     3.5  1112484727
# 582574                  Crime|Mystery|Thriller       1     3.5  1112484580

# %%
genome = genome_scores.merge(genome_tags, on = 'tagId', how = 'inner')

# %%
genome
# Out:
#           movieId  tagId  relevance      tag
# 0               1      1    0.02500      007
# 1               2      1    0.03975      007
# 2               3      1    0.04350      007
# 3               4      1    0.03725      007
# 4               5      1    0.04200      007
# ...           ...    ...        ...      ...
# 11709763   130578   1128    0.01325  zombies
# 11709764   130840   1128    0.13375  zombies
# 11709765   131013   1128    0.01625  zombies
# 11709766   131168   1128    0.01725  zombies
# 11709767   131170   1128    0.02175  zombies
#
# [11709768 rows x 4 columns]

# %%
user1 = movies_ratings_data[movies_ratings_data.userId == 1].head(5)
user1 = user1.reset_index(drop=True)

# %%
user2 = movies_ratings_data[movies_ratings_data.userId == 2].head(7)
user2 = user2.reset_index(drop=True)

# %%
user1
# Out:
#    movieId                                              title  \
# 0        2                                     Jumanji (1995)
# 1       29  City of Lost Children, The (Cité des enfants p...
# 2       32          Twelve Monkeys (a.k.a. 12 Monkeys) (1995)
# 3       47                        Seven (a.k.a. Se7en) (1995)
# 4       50                         Usual Suspects, The (1995)
#
#                                    genres  userId  rating   timestamp
# 0              Adventure|Children|Fantasy       1     3.5  1112486027
# 1  Adventure|Drama|Fantasy|Mystery|Sci-Fi       1     3.5  1112484676
# 2                 Mystery|Sci-Fi|Thriller       1     3.5  1112484819
# 3                        Mystery|Thriller       1     3.5  1112484727
# 4                  Crime|Mystery|Thriller       1     3.5  1112484580

# %%
user2
# Out:
#    movieId                                      title  \
# 0        3                    Grumpier Old Men (1995)
# 1       62                  Mr. Holland's Opus (1995)
# 2       70                 From Dusk Till Dawn (1996)
# 3      110                          Braveheart (1995)
# 4      242              Farinelli: il castrato (1994)
# 5      260  Star Wars: Episode IV - A New Hope (1977)
# 6      266                 Legends of the Fall (1994)
#
#                           genres  userId  rating  timestamp
# 0                 Comedy|Romance       2     4.0  974820889
# 1                          Drama       2     5.0  974820598
# 2  Action|Comedy|Horror|Thriller       2     5.0  974820691
# 3               Action|Drama|War       2     4.0  974820658
# 4                  Drama|Musical       2     3.0  974820776
# 5        Action|Adventure|Sci-Fi       2     5.0  974821014
# 6      Drama|Romance|War|Western       2     5.0  974820748

# %%
n = len(user1)
s = len(user2)

#""""""""""""""""""""""""""#
#     Matrice de coût      #
#""""""""""""""""""""""""""#
#   bewteen users 1 and 2  #
#       preferences        #

M = np.zeros((n, s))
M

for i in range(n):
    for j in range(s):
        
        # pour comparer la distance entre deux films, on prend les tags genomes 
        # des deux, ici ce sont vi et vj
        # ce qui donne la matrice de coût M
        # où Mij = 1 - sim(vi,vj) (cosinue similtary)
        
        # user1
        us1_mvId = user1.iloc[i][0] # pour récuperer le movieId
        v1 = genome_scores[genome_scores.movieId == us1_mvId].relevance.values

        # user2
        us2_mvId = user2.iloc[j][0] # pour récuprer le movieId
        v2 = genome_scores[genome_scores.movieId == us2_mvId].relevance.values
        
        M[i, j] = cosine(v1.reshape(1, -1), v2.reshape(1, -1))
    
M = pd.DataFrame(data = M, index = list(user1.title.values), columns=list(user2.title.values))

# %%
M
# Out:
#                                                     Grumpier Old Men (1995)  \
# Jumanji (1995)                                                     0.313482
# City of Lost Children, The (Cité des enfants pe...                 0.421913
# Twelve Monkeys (a.k.a. 12 Monkeys) (1995)                          0.405523
# Seven (a.k.a. Se7en) (1995)                                        0.386789
# Usual Suspects, The (1995)                                         0.344711
#
#                                                     Mr. Holland's Opus (1995)  \
# Jumanji (1995)                                                       0.347761
# City of Lost Children, The (Cité des enfants pe...                   0.423167
# Twelve Monkeys (a.k.a. 12 Monkeys) (1995)                            0.419272
# Seven (a.k.a. Se7en) (1995)                                          0.415210
# Usual Suspects, The (1995)                                           0.352174
#
#                                                     From Dusk Till Dawn (1996)  \
# Jumanji (1995)                                                        0.448752
# City of Lost Children, The (Cité des enfants pe...                    0.450774
# Twelve Monkeys (a.k.a. 12 Monkeys) (1995)                             0.417914
# Seven (a.k.a. Se7en) (1995)                                           0.300731
# Usual Suspects, The (1995)                                            0.314965
#
#                                                     Braveheart (1995)  \
# Jumanji (1995)                                               0.364774
# City of Lost Children, The (Cité des enfants pe...           0.362767
# Twelve Monkeys (a.k.a. 12 Monkeys) (1995)                    0.331540
# Seven (a.k.a. Se7en) (1995)                                  0.299987
# Usual Suspects, The (1995)                                   0.254655
#
#                                                     Farinelli: il castrato (1994)  \
# Jumanji (1995)                                                           0.469818
# City of Lost Children, The (Cité des enfants pe...                       0.315885
# Twelve Monkeys (a.k.a. 12 Monkeys) (1995)                                0.383743
# Seven (a.k.a. Se7en) (1995)                                              0.384674
# Usual Suspects, The (1995)                                               0.354001
#
#                                                     Star Wars: Episode IV - A New Hope (1977)  \
# Jumanji (1995)                                                                       0.301235
# City of Lost Children, The (Cité des enfants pe...                                   0.288331
# Twelve Monkeys (a.k.a. 12 Monkeys) (1995)                                            0.279748
# Seven (a.k.a. Se7en) (1995)                                                          0.342937
# Usual Suspects, The (1995)                                                           0.275666
#
#                                                     Legends of the Fall (1994)
# Jumanji (1995)                                                        0.430599
# City of Lost Children, The (Cité des enfants pe...                    0.408456
# Twelve Monkeys (a.k.a. 12 Monkeys) (1995)                             0.419714
# Seven (a.k.a. Se7en) (1995)                                           0.410744
# Usual Suspects, The (1995)                                            0.361112

# %% [markdown]
# ### II - Plan de transport
